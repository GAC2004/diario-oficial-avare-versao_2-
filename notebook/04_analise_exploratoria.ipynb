# %% [markdown]
# # Notebook 04 - Avaliação do Sistema
#
# Apresenta um fluxo simples de consulta e análise dos resultados.

# %%
import pandas as pd

df=pd.read_csv('../data/metadata.csv')
print('Total de documentos:', len(df))
print(df.head())
